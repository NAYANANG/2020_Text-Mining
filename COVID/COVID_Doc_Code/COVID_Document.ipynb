# %%
from konlpy.tag import Komoran

komoran=Komoran()
import pandas as pd
import os
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
def Corona_POS_tag(x):
    Corona=pd.read_csv('/home/u1013/schtm_osy_lsm_kjh/COVID/COVID_Dataset/{0}'.format(x),encoding='utf-8')
    Corona=Corona.drop('Unnamed: 0',axis=1)
    Corona_text=np.array(Corona.loc[:,'Text'].tolist())
    Corona_pos_words=[]
    for i in range(len(Corona)):
        list=[]
        list+=komoran.pos(Corona_text[i])
        Corona_pos_words.append(list)
    total_text=[]
    pos_text=[]
    keyword=['코로나방역','방역','코로나바이러스','19']
    for j in range(len(Corona)):
        text_list=Corona_pos_words[j]
        for i in range(len(text_list)):
            if text_list[i][1] not in ('SF','SP','SS','SE','SO','SW') and text_list[i][0] not in keyword:
                pos_text.append(text_list[i][:])
        total_text.append(pos_text)
        pos_text=[]
    sub_pos=[]
    selected_pos=[]
    for j in range(len(total_text)):
        pos_list=total_text[j]
        for i in range(len(pos_list)):
            if pos_list[i][1] in ('NNG','NNP'):
                sub_pos.append(pos_list[i][0])
        selected_pos.append(sub_pos)
        sub_pos=[]
    for z in range(len(selected_pos)):
        selected_pos[z]=" ".join(selected_pos[z])
    return selected_pos

# %%
tag=Corona_POS_tag('COVID_TV조선.csv')

# %%
import pickle

with open('COVID_TV조선.txt','wb') as f:
    pickle.dump(tag,f)

# %%
with open('COVID_TV조선.txt','rb') as f:
    read=pickle.load(f)
    print(read)
# Out:
# ['다음 동영상 재생 취소 3분 미리 보기 종료 영상 감상 아래 구매 이용 구매 문재인 대통령 국회 시정 연설 발언 코로나 유행 세계 격변 대공황 이후 최악 경제 위기 한국 위기 나라 전 세계 증명 경제 세계 선방 세계 모범 대한민국 자부심 확산 위기 때 성공 극복 전 세계 코로나 확산 속 한국 완화 매우 예외 선방 국민 의료진 감사 한국 경제 회복 나라 평가 차례 추경 신속 결정 국회 감사 경제 반등 분기 성장률 반등 확산 성과 경제 동반 성공', '문재인 대통령 오늘 오후 메시지 수능 시험 하루 수험 응원 문 대통령 수능 준비 코로나 상황 시험 걱정 마음 목도리 마음 마음 힘 이 부모 다 독 여준 선생님 마음 여러분 마음 문 대통령 수험 존재 날 응원 자신 침착 격려 문 대통령 지난달 트위터 메시지 전 세계 수능 주목 있다 예외 무사 안전 수능 우수 입시 관련 온라인 커뮤니티 에선 일부 수험 수능 연기 불가 이유 우수 코로나 확산 속 수능 불안 불만 토로 신은 기자', '당국 러 위 데이 코로나 확산 우려 다중 이용 시설 방문 자제 당부 5월 이태원 클럽 방문자 중심 수도권 규모 집단 감염 발생 거리 두기 완화 상황 러 위 행사 확산 급증 권준 중앙 대책 본부 부본부장 정례 브리핑 코로나 밀 밀집 밀접 밀폐 환경 곳 발생 있다 발열 호흡기 증상 경우 사람 행사 클럽 주점 다중 이용 시설 방문 자제 신체 접촉 노래 침 방울이 발생 행위 자제 음식 실천 시간 모임 이후 증상 검사 당부 정은혜 기자', '경기도 남양주 요양원 입 소자 종사자 무더기 코로나 확진 판정 당국 해당 건물 전체 코 호 격리 조치 당국 남양주 해당 요양원 어제 입 소자 처음 확진 이후 입 소자 직원 전수 검사 결과 추가 확진 판정 해당 요양원 입