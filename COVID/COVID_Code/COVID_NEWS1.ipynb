# %%
from selenium import webdriver
import os
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv
import urllib.request as ur

# %%
def news1(keyword):
    #크롬 드라이버 가져오기
    browser=webdriver.Chrome('chromedriver.exe')
    #news1 홈페이지 들어가기
    browser.get('https://www.news1.kr')
    #keyword 검색 후 기사 목록들 가져오기
    browser.find_element_by_xpath('//*[@id="query"]').send_keys(keyword)
    browser.find_element_by_xpath('//*[@id="pront_top_search"]/button').click()
    browser.find_element_by_xpath('//*[@id="lnb"]/ul/li[2]/a').click()
    browser.find_element_by_xpath('//*[@id="lnb"]/div/fieldset[1]/ul/li[1]/a').click()
    browser.find_element_by_xpath('//*[@id="range_3M"]/a').click()
    browser.find_element_by_xpath('//*[@id="lnb"]/div/fieldset[2]/div/div/a').click()
    
    #뉴스 기사 목록에서 url 코드들을 가져와 리스트에 저장하기
    url=[]
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul > li > dl > dt >a ')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[1]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul > li > dl > dt >a ')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[2]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul > li > dl > dt >a ')
    for urls in attr:
        url.append(urls['href'])
    
    #저장된 리스트에서 하나 씩 불러와 뉴스 제목과 본문들을 dictionary형태로 저장해준다.
    dict={}
    for i in range(len(url)):
        browser.get(url[i])
        time.sleep(1)
        html=browser.page_source
        soup=BeautifulSoup(html,'html.parser')
        title=soup.find('div',{'class':'title'}).text
        title=title.replace('\r','').replace('\n','').replace('\t','')
        text=soup.find('div',{'class':'detail sa_area'}).text
        text=text.replace('\n','').replace('\t','').replace('\r','').replace('\xa0','')
        dict[title]=text
  
    #dictonary파일을 csv파일로 변환한다.
    with open('news1_{0}.csv'.format(keyword),'w',-1,encoding='utf-8') as f:
        w=csv.writer(f)
        w.writerow(dict.keys())
        w.writerow(dict.values())
    
    #수정을 위해서 csv파일을 불러온다.
    news1=pd.read_csv('C:/Users/dsp12/Downloads/news1_{0}.csv'.format(keyword),encoding='utf-8')
    #행렬전환
    news1=news1.transpose()
    list_b=list
    title=list_b(news1.index)
    list_c=list
    text=news1[0]
    text=list_c(text)
    source=pd.DataFrame({'Title':title,'Text':text})
    #60개의 기사들만 뽑아낸다.
    source=source.iloc[:60]
    #Press이름의 열을 만들어 언론사 이들을 넣어준다.
    source['Press']='news1'
    source=source[['Press','Title','Text']]
    source.to_csv('news1_{0}.csv'.format(keyword),encoding='utf-8-sig')

# %%
#크롬 드라이버 가져오기
browser=webdriver.Chrome('chromedriver.exe')
#news1 홈페이지 들어가기
browser.get('https://www.news1.kr')
#keyword 검색 후 기사 목록들 가져오기
browser.find_element_by_xpath('//*[@id="query"]').send_keys('코로나방역')
browser.find_element_by_xpath('//*[@id="pront_top_search"]/button').click()
browser.find_element_by_xpath('//*[@id="lnb"]/ul/li[2]/a').click()
browser.find_element_by_xpath('//*[@id="lnb"]/div/fieldset[1]/ul/li[1]/a').click()
browser.find_element_by_xpath('//*[@id="range_3M"]/a').click()
browser.find_element_by_xpath('//*[@id="lnb"]/div/fieldset[2]/div/div/a').click()

# %%
#뉴스 기사 목록에서 url 코드들을 가져와 리스트에 저장하기
url=[]
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul > li > dl > dt >a ')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[1]').click()
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul > li > dl > dt >a ')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[2]').click()
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul > li > dl > dt >a ')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[3]').click()
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul > li > dl > dt >a ')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[4]').click()
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul > li > dl > dt >a ')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[5]').click()
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul > li > dl > dt >a ')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content"]/div[3]/span/a[6]').click()
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul > li > dl > dt >a ')
for urls in attr:
    url.append(urls['href'])

# %%
len(url)
# Out:
# 140

# %%
dict={}
for i in range(len(url)):
    browser.get(url[i])
    time.sleep(3)
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    title=soup.find('div',{'class':'title'}).text
    title=title.replace('\r','').replace('\n','').replace('\t','')
    text=soup.find('div',{'class':'detail sa_area'}).text
    text=text.replace('\n','').replace('\t','').replace('\r','').replace('\xa0','')
    dict[title]=text

# %%
#dictonary파일을 csv파일로 변환한다.
with open('COVID_NEWS1.csv','w',-1,encoding='utf-8') as f:
    w=csv.writer(f)
    w.writerow(dict.keys())
    w.writerow(dict.values())
    
#수정을 위해서 csv파일을 불러온다.
news1=pd.read_csv('./COVID_NEWS1.csv',encoding='utf-8')
#행렬전환
news1=news1.transpose()
list_b=list
title=list_b(news1.index)
list_c=list
text=news1[0]
text=list_c(text)
source=pd.DataFrame({'Title':title,'Text':text})
#60개의 기사들만 뽑아낸다.
source=source.iloc[:100]
#Press이름의 열을 만들어 언론사 이들을 넣어준다.
source['Press']='news1'
source=source[['Press','Title','Text']]
source.to_csv('COVID_NEWS1.csv',encoding='utf-8-sig')
