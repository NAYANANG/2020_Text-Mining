# %%
from selenium import webdriver
import os
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv
import urllib.request as ur

# %%
def mbc(keyword):
    #크롬 드라이버 가져오기
    browser=webdriver.Chrome('chromedriver.exe')
    #mbc 홈페이지 들어가기
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=0'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    
    #뉴스 기사 목록에서 url 코드들 가져와서 저장하기
    url=[]
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=1'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe') 
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=2'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=3'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=4'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=5'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=6'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=7'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=8'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=9'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=10'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=11'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=12'.format('코로나방역'))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul.thumb_type > li > a')
    for urls in attr:
        url.append(urls['href'])
        
    #저장된 url들을 가져와서 제목과 본문을 뽑아낸 후 dictionary로 저장하기
    dict={}
    for i in range(len(url)):
        browser.get('https://imnews.imbc.com'+url[i])
        time.sleep(1)
        html=browser.page_source
        soup=BeautifulSoup(html,'html.parser')
        title=soup.find('h2',{'class':'art_title'}).text
        title=title.replace('\r','').replace('\n','').replace('\t','')
        text=soup.find('div',{'class':'news_txt'}).text
        text=text.replace('\n','').replace('\t','').replace('\r','')
        dict[title]=text
    #dictionary파일을 csv파일로 저장    
    with open('mbc_{}.csv'.format(keyword),'w',-1,encoding='utf-8') as f:
        w=csv.writer(f)
        w.writerow(dict.keys())
        w.writerow(dict.values())
    
    #수정을 위해 csv파일을 가져오기
    mbc=pd.read_csv('C:/Users/user/Downloads/MBC_{}.csv'.format(keyword),encoding='utf-8')
    #행렬전환
    mbc=mbc.transpose()
    list_b=list
    title=list_b(mbc.index)
    list_c=list
    text=mbc[0]
    text=list_c(text)
    source=pd.DataFrame({'Title':title,'Text':text})
    #60개의 기사들만 뽑아낸다.
    source=source.iloc[:100]
    #Press이름의 언론사 열을 붙힌다.
    source['Press']='MBC'
    source=source[['Press','Title','Text']]
    source.to_csv('MBC_{}.csv'.format(keyword),encoding='utf-8-sig')

# %%
mbc("코로나방역")
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-6-6a30fe719306> in <module>
# ----> 1 mbc("코로나방역")
#
# <ipython-input-2-30b95b413ed3> in mbc(keyword)
#     100     dict={}
#     101     for i in range(len(url)):
# --> 102         browser.get('https://imnews.imbc.com'+url[i])
#     103         time.sleep(1)
#     104         html=browser.page_source
#
# ~\Anaconda3\envs\nayanang\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\envs\nayanang\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\envs\nayanang\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 299.922
#   (Session info: chrome=87.0.4280.88)

# %%
#크롬 드라이버 가져오기
browser=webdriver.Chrome('chromedriver.exe')
#mbc 홈페이지 들어가기
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=0'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')

# %%
url=[]
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=1'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe') 
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=2'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=3'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=4'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=5'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=6'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=7'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=8'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=9'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=10'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=11'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=12'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=13'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=14'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=15'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=16'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=17'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=18'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=19'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=20'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=21'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=22'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=23'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=24'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=25'.format('코로나방역'))
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.thumb_type > li > a')
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://imnews.imbc.com/more/search/?search_kwd={}#page=26'.format('코로나방역'))

# %%
dict={}
for i in range(len(url)):
    browser.get('https://imnews.imbc.com'+url[i])
    time.sleep(5)
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    title=soup.find('h2',{'class':'art_title'}).text
    title=title.replace('\r','').replace('\n','').replace('\t','')
    text=soup.find('div',{'class':'news_txt'}).text
    text=text.replace('\n','').replace('\t','').replace('\r','')
    dict[title]=text
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-11-5525d06e0c3d> in <module>
#       1 dict={}
#       2 for i in range(len(url)):
# ----> 3     browser.get('https://imnews.imbc.com'+url[i])
#       4     time.sleep(1)
#       5     html=browser.page_source
#
# ~\Anaconda3\envs\nayanang\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\envs\nayanang\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\envs\nayanang\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 299.744
#   (Session info: chrome=87.0.4280.88)

# %%
len(dict)
# Out:
# 113

# %%
with open('COVID_MBC.csv','w',-1,encoding='utf-8') as f:
        w=csv.writer(f)
        w.writerow(dict.keys())
        w.writerow(dict.values())

# %%
#수정을 위해 csv파일을 가져오기
mbc=pd.read_csv('./COVID_MBC.csv',encoding='utf-8')
#행렬전환
mbc=mbc.transpose()
list_b=list
title=list_b(mbc.index)
list_c=list
text=mbc[0]
text=list_c(text)
source=pd.DataFrame({'Title':title,'Text':text})
#60개의 기사들만 뽑아낸다.
source=source.iloc[:100]
#Press이름의 언론사 열을 붙힌다.
source['Press']='MBC'
source=source[['Press','Title','Text']]
source.to_csv('COVID_MBC.csv',encoding='utf-8-sig')
