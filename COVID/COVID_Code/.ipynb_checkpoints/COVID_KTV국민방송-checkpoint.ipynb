# %%
from selenium import webdriver
import os
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv
import urllib.request as ur

# %%
    #크롬 드라이버 가져오기
    browser=webdriver.Chrome('chromedriver.exe')
    #ktv홈페이지 입장
    browser.get('http://www.ktv.go.kr/')
    browser.find_element_by_xpath('//*[@id="header_search_btn"]').click()
    #keyword 검색
    browser.find_element_by_xpath('//*[@id="header_query"]').send_keys('코로나방역')
    browser.find_element_by_xpath('//*[@id="header"]/div[2]/div/div[2]/div[2]/form/button').click()
    browser.find_element_by_xpath('//*[@id="contents"]/div[2]/ul/li[2]/a').click()
    
    #뉴스 기사 목록에서 url코드들 전부 가져와서 url리스트에 저장하기
    url=[]
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[3]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[4]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[5]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[6]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[7]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[8]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[9]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[10]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[11]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[12]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[3]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[4]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])
    browser.find_element_by_xpath('//*[@id="contents"]/div[6]/a[5]').click()
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('div.result-cont > ul.board-list01 >li > a')
    for urls in attr:
        url.append(urls['href'])

# %%
len(url)
# Out:
# 140

# %%
dict={}
for i in range(len(url)):
    browser.get('http://www.ktv.go.kr'+url[i])
    time.sleep(1)
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    title=soup.select('div.top_view > div.lft>h2')
    title=title[0].text
    title=title.replace('\r','').replace('\n','').replace('\t','')
    text=soup.find('div',{'class':'article zoominout'}).text
    text=text.replace('\n','').replace('\t','').replace('\r','').replace('\xa0','')
    dict[title]=text

# %%
with open('./COVID_KTV국민방송.csv','w',-1,encoding='utf-8') as f:
    w=csv.writer(f)
    w.writerow(dict.keys())
    w.writerow(dict.values())

# %%
#수정을 위해csv파일을 읽어오기
KTV=pd.read_csv('./COVID_KTV국민방송.csv',encoding='utf-8')
#행렬전환
KTV=KTV.transpose()
list_B=list
title=list_B(KTV.index)
list_C=list
text=KTV[0]
text=list_C(text)
source=pd.DataFrame({'Title':title,'Text':text})
#60개의 기사들만 뽑아낸다.
source=source.iloc[:100]
#Press이름의 언론사 열을 붙힌다.
source['Press']='KTV국민방송'
source=source[['Press','Title','Text']]
source.to_csv('COVID_KTV국민방송.csv',encoding='utf-8-sig')

# %%
pd.read_csv('./COVID_KTV국민방송.csv',encoding='utf-8')
# Out:
#     Unnamed: 0    Press                                      Title  \
# 0            0  KTV국민방송                   신규 확진 689명···신속항원검사 건보적용
# 1            1  KTV국민방송          코로나19 속 한국·캄보디아 교류 현황은? [세계 속 한국]
# 2            2  KTV국민방송                    코로나19 백신 도입···효능과 부작용은?
# 3            3  KTV국민방송                    14일부터 3주간 수도권 '집중 검사기간'
# 4            4  KTV국민방송                      다문화가족 포용 대책 여성가족부 브리핑
# ..         ...      ...                                        ...
# 95          95  KTV국민방송  '숙박 할인권 사업' 코로나19 확산 키운 불씨됐다? [사실은 이렇습니다]
# 96          96  KTV국민방송            "안전한 수능 위해 모든 일상모임 멈춰야" [브리핑타임]
# 97          97  KTV국민방송            신규확진 451명···"수능일 새벽 확진돼도 응시 가능"
# 98          98  KTV국민방송              신규 확진 451명···"수능 전 학원·독서실 위험"
# 99          99  KTV국민방송                  문 대통령 "확실한 경기반등 위해 힘 모아야"
#
#                                                  Text
# 0   박천영 앵커>코로나 현황 살펴봅니다.국내 신규 확진자가 사흘째 700명 가까이 집계...
# 1   김용민 앵커>동남아시아 국가들이 코로나19 타격으로 몸살을 앓고 있는 가운데, 캄보...
# 2   최대환 앵커>신종 코로나 바이러스 감염증 '3차 대유행'의 확산세가 지속되면서 신규...
# 3   김용민 앵커>수도권 지역을 중심으로 코로나19 확진자가 폭증하는 가운데 방역당국이 ...
# 4   다문화가족 포용 대책 여성가족부 브리핑김경선 / 여성가족부 차관(장소: 정부서울청사...
# ..                                                ...
# 95  최대환 앵커>계속해서 또 다른 주제 자세히 살펴보겠습니다.정부에서는 코로나로 인해 ...
# 96  11월 초부터 코로나19 감염 확산세 지속 11월 30일 기준. 국내 신규 확진자 ...
# 97  유용화 앵커>오늘 뉴스, 코로나19 소식으로 시작하겠습니다.코로나19 3차 유행이 ...
# 98  박천영 앵커>코로나19 3차 유행이 현실화된 가운데, 전국 곳곳에서 산발적인 집단감...
# 99  신경은 앵커>국무회의를 주재한 문재인 대통령은, 3분기부터 시작된 경기 반등의 흐름...
#
# [100 rows x 4 columns]
