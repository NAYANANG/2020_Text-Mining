# %%
from selenium import webdriver
import os
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv
import urllib.request as ur

# %%
def Yonhap(keyword):
    #크롬 드라이버 가져오기
    browser=webdriver.Chrome('chromedriver.exe')
    #연합뉴스 홈페이지 들어가서 기사 목록 가져오기
    browser.get('https://www.yonhapnewstv.co.kr/search/news?q={0}&sortField=score&sort=on&startDate=&endDate='.format(keyword))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul >li >div> div> a') 
    
    #기사 url들을 list형태로 저장해준다.
    url=[]
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://www.yonhapnewstv.co.kr/search/news?pageNo=2&q={0}&sortField=score&sort=on&startDate=&endDate='.format(keyword))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul >li >div> div> a') 
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://www.yonhapnewstv.co.kr/search/news?pageNo=3&q={0}&sortField=score&sort=on&startDate=&endDate='.format(keyword))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul >li >div> div> a') 
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://www.yonhapnewstv.co.kr/search/news?pageNo=4&q={0}&sortField=score&sort=on&startDate=&endDate='.format(keyword))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul >li >div> div> a') 
    for urls in attr:
        url.append(urls['href'])
    browser=webdriver.Chrome('chromedriver.exe')
    browser.get('https://www.yonhapnewstv.co.kr/search/news?pageNo=5&q={0}&sortField=score&sort=on&startDate=&endDate='.format(keyword))
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    attr=soup.select('ul >li >div> div> a') 
    for urls in attr:
        url.append(urls['href'])
    
    #url list에서 하나씩 불러와 기사본문과 제목을 가져와 dictionary로 만들어준다.
    dict={}
    for i in range(len(url)):
        browser.get('https://www.yonhapnewstv.co.kr/'+url[i])
        time.sleep(1)
        html=browser.page_source
        soup=BeautifulSoup(html,'html.parser')
        title=soup.find('strong',{'class':'title'}).text
        title=title.replace('\r','').replace('\n','').replace('\t','')
        text=soup.find('div',{'id':'articleBody'}).text
        text=text.replace('\n','').replace('\t','').replace('\r','')
        dict[title]=text
        
    #dictionary를 csv로 만들어 저장해준다.
    with open('연합뉴스_{0}.csv'.format(keyword),'w',-1,encoding='utf=8') as f:
        w=csv.writer(f)
        w.writerow(dict.keys())
        w.writerow(dict.values())

    #수정을 위해 csv파일를 불러온다.
    yonhap=pd.read_csv('C:/Users/dsp12/Downloads/연합뉴스_{0}.csv'.format(keyword),encoding='utf-8')
    #행렬전환
    yonhap=yonhap.transpose()
    list_b=list
    title=list_b(yonhap.index)
    list_c=list
    text=yonhap[0]
    text=list_c(text)
    source=pd.DataFrame({'Title':title,'Text':text})
    #60개의 행만 뽑아낸다.
    source=source.iloc[:60]
    #Press열을 만들어 언론사이름을 넣어준다.
    source['Press']='연합뉴스'
    source=source[['Press','Title','Text']]

# %%
#크롬 드라이버 가져오기
browser=webdriver.Chrome('chromedriver.exe')
#연합뉴스 홈페이지 들어가서 기사 목록 가져오기
browser.get('https://yonhapnewstv.co.kr/search/news?pageNo=1&q=%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%A9%EC%97%AD')
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul >li >div> div> a') 
    
#기사 url들을 list형태로 저장해준다.
url=[]
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://yonhapnewstv.co.kr/search/news?pageNo=2&q=%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%A9%EC%97%AD')
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul >li >div> div> a') 
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://yonhapnewstv.co.kr/search/news?pageNo=3&q=%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%A9%EC%97%AD')
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul >li >div> div> a') 
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://yonhapnewstv.co.kr/search/news?pageNo=4&q=%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%A9%EC%97%AD')
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul >li >div> div> a') 
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://yonhapnewstv.co.kr/search/news?pageNo=5&q=%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%A9%EC%97%AD')
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul >li >div> div> a') 
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://yonhapnewstv.co.kr/search/news?pageNo=6&q=%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%A9%EC%97%AD')
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul >li >div> div> a') 
for urls in attr:
    url.append(urls['href'])
browser=webdriver.Chrome('chromedriver.exe')
browser.get('https://yonhapnewstv.co.kr/search/news?pageNo=7&q=%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%A9%EC%97%AD')
html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul >li >div> div> a') 
for urls in attr:
    url.append(urls['href'])

# %%
url
# Out:
# ['/news/MYH20201211004700038',
#  '/news/MYH20201208010600038',
#  '/news/MYH20201207013900038',
#  '/news/MYH20201207003800038',
#  '/news/MYH20201206002400038',
#  '/news/MYH20201205004500038',
#  '/news/MYH20201204007900038',
#  '/news/MYH20201203022700641',
#  '/news/MYH20201203018600641',
#  '/news/MYH20201203006300038',
#  '/news/MYH20201202017500038',
#  '/news/MYH20201202008900038',
#  '/news/MYH20201202004100038',
#  '/news/MYH20201201025000641',
#  '/news/MYH20201201021600641',
#  '/news/MYH20201201000100640',
#  '/news/MYH20201128002000038',
#  '/news/MYH20201124007200641',
#  '/news/MYH20201123007600038',
#  '/news/MYH20201120012800641',
#  '/news/MYH20201118006100038',
#  '/news/MYH20201117012000038',
#  '/news/MYH20201116022400641',
#  '/news/MYH20201116019700641',
#  '/news/MYH20201116008200641',
#  '/news/MYH20201115008900038',
#  '/news/MYH20201115008600038',
#  '/news/MYH20201110008900038',
#  '/news/MYH20201108009800038',
#  '/news/MYH20201104006800038',
#  '/news/MYH20201103009900038',
#  '/news/MYH20201101001900038',
#  '/news/MYH20201031004300038',
#  '/news/MYH20201028006300038',
#  '/news/MYH20201027015400038',
#  '/news/MYH20201027009700038',
#  '/news/MYH20201027004300038',
#  '/news/MYH20201026006300038',
#  '/news/MYH20201024004100038',
#  '/news/MYH20201023020300038',
#  '/news/MYH20201023019000038',
#  '/news/MYH20201023017900038',
#  '/news/MYH20201021006400038',
#  '/news/MYH20201020009600038',
#  '/news/MYH20201016021400038',
#  '/news/MYH20201015011300038',
#  '/news/MYH20201014001100640',
#  '/news/MYH20201014000100640',
#  '/news/MYH20201012018900038',
#  '/news/MYH20201012014000038',
#  '/news/MYH20201010008500641',
#  '/news/MYH20201010005600038',
#  '/news/MYH20201010001400641',
#  '/news/MYH20201007006100038',
#  '/news/MYH20201005007400038',
#  '/news/MYH20201003009700038',
#  '/news/MYH20201003004600641',
#  '/news/MYH20201002006600038',
#  '/news/MYH20200930013300641',
#  '/news/MYH20200930010900038',
#  '/news/MYH20200930010600038',
#  '/news/MYH20200930004500038',
#  '/news/MYH20200930003400038',
#  '/news/MYH20200930000200038',
#  '/news/MYH20200929013700641',
#  '/news/MYH20200929011400641',
#  '/news/MYH20200928008200038',
#  '/news/MYH20200925017700038',
#  '/news/MYH20200925015400038',
#  '/news/MYH20200925007500038',
#  '/news/MYH20200925006400038',
#  '/news/MYH20200925004400038',
#  '/news/MYH20200924011600038',
#  '/news/MYH20200923019400641',
#  '/news/MYH20200923014900641',
#  '/news/MYH20200922018900038',
#  '/news/MYH20200922012400038',
#  '/news/MYH20200922008900038',
#  '/news/MYH20200919008000641',
#  '/news/MYH20200919004700038',
#  '/news/MYH20200918006000038',
#  '/news/MYH20200918005700038',
#  '/news/MYH20200913008600038',
#  '/news/MYH20200910010700038',
#  '/news/MYH20200909011400038',
#  '/news/MYH20200908022900038',
#  '/news/MYH20200908011700038',
#  '/news/MYH20200908000500640',
#  '/news/MYH20200906008200038',
#  '/news/MYH20200905004100038',
#  '/news/MYH20200903009000038',
#  '/news/MYH20200902004800038',
#  '/news/MYH20200901007500038',
#  '/news/MYH20200831007900038',
#  '/news/MYH20200825013000640',
#  '/news/MYH20200825011600641',
#  '/news/MYH20200825009600641',
#  '/news/MYH20200825007500641',
#  '/news/MYH20200825006300038',
#  '/news/MYH20200825005900038',
#  '/news/MYH20200824021600641',
#  '/news/MYH20200824018800641',
#  '/news/MYH20200824014400038',
#  '/news/MYH20200824010400038',
#  '/news/MYH20200823007000038',
#  '/news/MYH20200821020900641',
#  '/news/MYH20200821019900641',
#  '/news/MYH20200821016600038',
#  '/news/MYH20200821015700641',
#  '/news/MYH20200821010500038',
#  '/news/MYH20200821010400038',
#  '/news/MYH20200821010100038',
#  '/news/MYH20200821010000038',
#  '/news/MYH20200820021200641',
#  '/news/MYH20200820011100038',
#  '/news/MYH20200820010800641',
#  '/news/MYH20200820009200641',
#  '/news/MYH20200820007000641',
#  '/news/MYH20200819010200641',
#  '/news/MYH20200818022500038',
#  '/news/MYH20200818018200038',
#  '/news/MYH20200818015400641',
#  '/news/MYH20200818015200641',
#  '/news/MYH20200818004900038',
#  '/news/MYH20200817006600038',
#  '/news/MYH20200815002200038',
#  '/news/MYH20200814011300038',
#  '/news/MYH20200813005700038',
#  '/news/MYH20200812022300038',
#  '/news/MYH20200812003500038',
#  '/news/MYH20200809011600038',
#  '/news/MYH20200805009500038',
#  '/news/MYH20200803008300038',
#  '/news/MYH20200803004400038',
#  '/news/MYH20200802004000038',
#  '/news/MYH20200731015600038',
#  '/news/MYH20200731006900038',
#  '/news/MYH20200731001800038',
#  '/news/MYH20200730013000038',
#  '/news/MYH20200730007300038']

# %%
#url list에서 하나씩 불러와 기사본문과 제목을 가져와 dictionary로 만들어준다.
browser=webdriver.Chrome('chromedriver.exe')
dict={}
for i in range(len(url)):
    browser.get('https://www.yonhapnewstv.co.kr/'+url[i])
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    title=soup.find('strong',{'class':'title'}).text
    title=title.replace('\r','').replace('\n','').replace('\t','')
    text=soup.find('div',{'id':'articleBody'}).text
    text=text.replace('\n','').replace('\t','').replace('\r','')
    dict[title]=text

# %%
#dictionary를 csv로 만들어 저장해준다.
with open('COVID_연합뉴스TV.csv','w',-1,encoding='utf=8') as f:
    w=csv.writer(f)
    w.writerow(dict.keys())
    w.writerow(dict.values())

#수정을 위해 csv파일를 불러온다.
yonhap=pd.read_csv('./COVID_연합뉴스TV.csv',encoding='utf-8')
#행렬전환
yonhap=yonhap.transpose()
list_b=list
title=list_b(yonhap.index)
list_c=list
text=yonhap[0]
text=list_c(text)
source=pd.DataFrame({'Title':title,'Text':text})
#100개의 행만 뽑아낸다.
source=source.iloc[:100]
#Press열을 만들어 언론사이름을 넣어준다.
source['Press']='연합뉴스'
source=source[['Press','Title','Text']]
source.to_csv('COVID_연합뉴스TV.csv',encoding='utf-8-sig')

# %%
pd.read_csv('./COVID_연합뉴스TV.csv',encoding='utf-8')
# Out:
#     Unnamed: 0 Press                                    Title  \
# 0            0  연합뉴스       [현장연결] 정총리 "사투 속 버티고 있어…방역수칙 준수해야"
# 1            1  연합뉴스      [현장연결] 질병청 "모든 모임과 약속 취소…방역수칙 지켜달라"
# 2            2  연합뉴스       [현장연결] 문대통령, 靑회의 주재…방역 강화·검찰 개혁 강조
# 3            3  연합뉴스    [한반도 브리핑] 北 "확진자 없다"…코로나 방역 '최고단계' 격상
# 4            4  연합뉴스                  코로나19 속 대입 논술고사 "방역 철저"
# ..         ...   ...                                      ...
# 95          95  연합뉴스   [현장연결] 질본 "방역조치만으로는 한계…사람간 접촉 최대한 줄여야"
# 96          96  연합뉴스        [현장연결] 정부, 코로나19 방역 방해 엄정대응 방침 발표
# 97          97  연합뉴스  [현장연결] 추미애 "악의적 방역활동 저해 구속수사…법정 최고형 구형"
# 98          98  연합뉴스                 코로나19 비상…대중교통 고강도 방역 이어가
# 99          99  연합뉴스               대전경찰, 코로나19 방역 지침 어긴 7명 송치
#
#                                                  Text
# 0   닫기[현장연결] 정총리 "사투 속 버티고 있어…방역수칙 준수해야"정세균 국무총리가 ...
# 1   닫기[현장연결] 질병청 "모든 모임과 약속 취소…방역수칙 지켜달라"중앙방역대책본부가...
# 2   닫기[현장연결] 문대통령, 靑회의 주재…방역 강화·검찰 개혁 강조[문재인 / 대통령...
# 3   닫기[한반도 브리핑] 北 "확진자 없다"…코로나 방역 '최고단계' 격상<출연 : 김...
# 4   닫기코로나19 속 대입 논술고사 "방역 철저"[앵커]수능은 끝났지만 대입 논술고사가...
# ..                                                ...
# 95  닫기[현장연결] 질본 "방역조치만으로는 한계…사람간 접촉 최대한 줄여야"중앙방역대책...
# 96  닫기[현장연결] 정부, 코로나19 방역 방해 엄정대응 방침 발표정부가 코로나19 방...
# 97  닫기[현장연결] 추미애 "악의적 방역활동 저해 구속수사…법정 최고형 구형"[추미애 ...
# 98  닫기코로나19 비상…대중교통 고강도 방역 이어가[뉴스리뷰][앵커]코로나19 확진자가...
# 99  닫기대전경찰, 코로나19 방역 지침 어긴 7명 송치대전지방경찰청이 코로나19 방역 ...
#
# [100 rows x 4 columns]
