# %%
import pickle

def n_gram(keyword):
    with open('/home/u1016/schtm_osy_lsm_kjh/POS_Tag/{0}_코로나방역_Noun_doc.txt'.format(keyword),'rb') as f:
        Doc=read=pickle.load(f)
    n_gram=[]
    for i in range(len(Doc)):
        n_sub=[]
        words=Doc[i].split()
        for j in range(len(words)-1):
            n_sub.append(words[j]+words[j+1])
        n_gram.append(n_sub)

    with open('{0}_코로나방역_n_gram.txt'.format(keyword),'wb') as f:
        pickle.dump(n_gram,f)     
    with open('{0}_코로나방역_n_gram.txt'.format(keyword),'rb') as f:
        read=pickle.load(f)
        print(read)

# %%
n_gram('JTBC')
# Out:
# [['세계코로나', '코로나확산', '확산인해', '인해외식', '외식행사', '행사모임', '모임군중', '군중자체', '자체경각심', '경각심고조', '고조세계', '세계경제', '경제전반', '전반위축', '위축이번', '이번신종', '신종코로나', '코로나말', '말감염', '감염신체', '신체옷', '옷바이러스', '바이러스간접', '간접감염', '감염우려', '우려제기', '제기다중', '다중이용', '이용시설', '시설불안감', '불안감증폭', '증폭실정', '실정지금', '지금건물', '건물출입', '출입일반', '일반마스크', '마스크착용', '착용확인', '확인손소독', '손소독비치', '비치수준', '수준우수', '우수경우', '경우화상', '화상카메라', '카메라설치', '설치접촉', '접촉체온계', '체온계별도', '별도모니터링', '모니터링요원', '요원측정', '측정하지', '하지대형', '대형병원', '병원마트', '마트학교', '학교규모', '규모인원', '인원동시', '동시다중', '다중이용', '이용시설', '시설경우', '경우생활', '생활한계', '한계상황', '상황건물', '건물출입', '출입최적화', '최적화어', '어마일', '마일게이트', '게이트개발', '개발코로나', '코로나대응', '대응이', '이프티', '프티솔루션', '솔루션기업', '기업어', '어마일', '마일건물', '건물출입', '출입자동', '자동발열', '발열체크', '체크살균', '살균소독', '소독실시간', '실시간통과', '통과게이트', '게이트어', '어마일', '마일게이트', '게이트세계', '세계최초', '최초출시', '출시순수', '순수국내', '국내기술', '기술개발', '개발어', '어마일', '마일게이트', '게이트모니터링', '모니터링기능', '기능특화', '특화발열', '발열감지', '감지카메라', '카메라건물', '건물출입', '출입체온', '체온미터', '미터거리', '거리실시간', '실시간감지', '감지정상', '정
# ...
