# %%
import pickle

# %%
def n_gram(keyword):
    with open('/home/u1013/schtm_osy_lsm_kjh/POS_Tag/{0}_Noun_doc.txt'.format(keyword),'rb') as f:
        Doc=read=pickle.load(f)
    n_gram=[]
    for i in range(len(Doc)):
        n_sub=[]
        words=Doc[i].split()
        for j in range(len(words)-1):
            n_sub.append(words[j]+words[j+1])
        n_gram.append(n_sub)

    with open('{0}_n_gram.txt'.format(keyword),'wb') as f:
        pickle.dump(n_gram,f)     
    with open('{0}_n_gram.txt'.format(keyword),'rb') as f:
        read=pickle.load(f)
        print(read)

# %%
n_gram('한국경제TV_부동산정책')
# Out:
# [['안철수국민의당', '국민의당대표', '대표오전', '오전서울', '서울여의도', '여의도국회', '국회최고', '최고위원', '위원회의', '회의모두', '모두발언', '발언사진', '사진뉴스1', '뉴스1안철수', '안철수국민의당', '국민의당대표', '대표사진', '사진김현미', '김현미국토', '국토교통부', '교통부장관', '장관부동산', '부동산정책', '정책책임자', '책임자해임', '해임요구', '요구안철수', '안철수대표', '대표최고', '최고위원', '위원회의', '회의야구', '야구타자', '타자내리', '내리타수', '타수안타', '안타기록', '기록타자', '타자대타', '대타기본', '기본문재인', '문재인정부', '정부부동산', '부동산정책', '정책차례', '차례집값', '집값폭등', '폭등김현미', '김현미장관', '장관관련', '관련기사', '기사대로', '대로인상', '인상종부', '종부세율', '세율당정', '당정이견', '이견박병석', '박병석서초', '서초아파트', '아파트판다', '판다다', '다주택', '주택투기', '투기여권', '여권사정', '사정변명', '변명보완책', '보완책압박', '압박금융', '금융위', '위전화', '전화청약', '청약당첨자', '당첨자식후', '식후땡', '땡부동산', '부동산집', '집정부', '정부내일', '내일부동산', '부동산세제', '세제대책', '대책발표', '발표부동산', '부동산주식', '주식영', '영끌', '끌투자', '투자올해', '올해가계', '가계대출', '대출증가', '증가폭', '폭역대', '역대최대', '최대부동산', '부동산인', '인국공', '국공악재', '악재지지', '지지반등', '반등30대', '30대상승', '상승주택', '주택김', '김남국', '남국북한', '북한생각', '생각정도', '정도부동산', '부동산규제', '규제김종인', '김종인정부', '정부정책', '정책실패', '실패공직자', '공직자부동산', '부동산거론', '거론중'
# ...
