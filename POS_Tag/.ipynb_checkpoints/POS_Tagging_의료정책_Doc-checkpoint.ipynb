# %%
from konlpy.tag import Komoran

komoran=Komoran()

import pandas as pd
import os
import numpy as np
def MED_POS_tag(x):
    MED=pd.read_csv('/home/u1013/schtm_osy_lsm_kjh/Crawling_Dataset/{0}'.format(x),encoding='utf-8')
    MED=MED.drop('Unnamed: 0',axis=1)
    MED_text=np.array(MED.loc[:,'Text'].tolist())
    MED_pos_words=[]
    for i in range(len(MED)):
        list=[]
        list+=komoran.pos(MED_text[i])
        MED_pos_words.append(list)
    total_text=[]
    pos_text=[]
    keyword=['의료정책']
    for j in range(len(MED)):
        text_list=MED_pos_words[j]
        for i in range(len(text_list)):
            if text_list[i][1] not in ('SF','SP','SS','SE','SO','SW') and text_list[i][0] not in keyword:
                pos_text.append(text_list[i][:])
        total_text.append(pos_text)
        pos_text=[]
    sub_pos=[]
    selected_pos=[]
    for j in range(len(total_text)):
        pos_list=total_text[j]
        for i in range(len(pos_list)):
            if pos_list[i][1] in ('NNG','NNP'):
                sub_pos.append(pos_list[i][0])
        selected_pos.append(sub_pos)
        sub_pos=[]
    for z in range(len(selected_pos)):
        selected_pos[z]=" ".join(selected_pos[z])
    return selected_pos

# %%
import wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from os import path

FONT_PATH = './gungsuh.ttf'

noun_text=''
for i in tag:
    noun_text=noun_text+' '+i
wordcloud=WordCloud(max_font_size=60,relative_scaling=.5,font_path=FONT_PATH).generate(noun_text)
plt.figure()
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
tag=MED_POS_tag('한국경제TV_의료정책.csv')

# %%
import pickle

with open('한국경제TV_의료정책_Noun_doc.txt','wb') as f:
    pickle.dump(tag,f)

# %%
with open('한국경제TV_의료정책_Noun_doc.txt','rb') as f:
    read=pickle.load(f)
    print(read)
# Out:
# ['한정애 더불어민주당 신임 정책위 의장 오전 국회 원내 대책 회의 발언 사진 연합뉴스 국회 보건 복지 위원장 한정애 더불어민주당 의원 사진 공공 의대 설립 의사 정원 확충 의료 계가 반발 정부 의료 정책 관련 당의 이름 강행 처리 논의 체 협의 안 법제 화해 처리 한정애 의원 이날 KBS 라디오 김경래 최강 시사 인터뷰 의대 정원 방법 말 한정애 의원 이제 주장 논의 토론 때 국회 장 정부 의료 정책 원점 논의 합의문 명문 요구 관련 기사 이낙연 김종인 대권 도전 바람결 있다 히포크라테스 선서 언급 뿔 의료 취임 선서 홍 남 겨냥 박근혜 사람 커밍아웃 인사 홍 남 철 비판 철 노력 이재명 의료진 북한 강제 파견 품격 시무 조 논쟁 여의도 브리핑 이재명 홍 남 인터뷰 확인 비난 당황 의사 국가시험 연기 이인영 난시 의료인 파견 기본 불의 제자 복지부 의대 교수 종합 최고 위원 청년 배려 이낙연 파격 인선 원점 재검토 단어 정부 국회 굴복 의미 정책 진행 때 소통 부족 원점 철회 방식 요구 정부 단어 집착 내용 뜻 의료 현장 상황 포함 논의 진행 협의 국회 이제 현장 당부 전공의 무기 파업 지속 지난달 서울 종로구 서울대병원 본관 앞 전문의 정부 추진 의대 정원 확대 공공 의대 설립 반대 피켓 시위 사진 허 문 찬 기자 .com 의사 국가 고시 연기 정부 상황 이어 국회 제안 국회 협의 기구 모두 공감대 표명 의료 서비스 지역 불균형 해소 필수 의료 강화 공공 의료 확충 의료 계가 제기 문제 의료 협의 틀 보장 보증 이상 약속 생각 그럼에도 불구하고 국회 요구 사항 말씀 주호영 미래 통합 당 원내대표 제안 여야 정 합의체 의료 신종 코로나바이러스 감염증 코로나 19 상황 안정 이후 불안감 9월 정기 국회 협의체 조준 혁 한경 닷 컴 기자 .com', '전공의 전임 의료 계가 의대 정원 확대 공공 의대 설립 정책 철회 촉구 집단 휴지 서울 종로구 서울대병원 본관 앞 전공의 정부 의료 정책 반대 피켓 사진 뉴스1 전공의 집단 휴지 의료 공백 발생 가운데 법무부 산하 국립 법무 병원 치료감호소 일 공무원 신분 의사 정부 의료 정책 반발 의미 사표 국립 법무 병원 정신 의사 입장 문 사직서 제출 후배 전공의 뜻 주장 전폭 지지 뜻 이 사회 안전 일해 국립 법무 병원 의사 본연 역할 책임 있다 의료 정책 진행 동료 의사 후배 전공의 자신 자리 침묵 관련 기사 속보 코로나 19 확산 상황 군의관 추가 요청 검토 속보 정부 국회 의료 약속 전공의 복귀 정 총리 전공의 업무 복귀 환자 고통 의료 정책 원점 재검토 의사 파업 돌파구 여 12 일 집단 휴지 전공의 가운데 근무 안해 정부 정원 확대 보류 전공의 문서 화해 복귀 서울 성모병원 외과 내달 수술 중단 교수 급 의료진 단체 행동 정부 의사 지역 의사 부족 공감 해법 증원 인상 불의 제자 복지부 의대 교수 종합 일 전공의 의사 논란 면허증 제시 신상 진정 의사 표현 본연 역할 의료 정책 환경 강조 정부 의과 정원 확대 공공 의대 설립 의료 정책 철회 전공의 행정명령 고발 취하 향후 의료 정책 의사 협회 지속 협의 요청 한편 정부 전공의 집단 휴지 발생 의료 공백 군의관 투입 방침 국방부 차로 파견 확정 인원 인천 의료원 인하대 병원 수도권 민간 의료 기관 지원 당초 중앙 사고 수습 본부 국방부 요청 군의관 규모 규모 국방부 일정 의료 기관 확정 나머지 인원 추가 지원 방침 이미경 한경 닷 컴 기자 .com', '박 능 후 보건 복지부 장관 오른쪽 최대 집 대한의사협회 장이 서울 광화문 정부서울청사 의 정 협의체 구성 합의서 체결 합의서 서명 뒤 악수 사진 연합뉴스 여의도 브리핑 정당 주목 이슈 공식 입장 화제 때 이슈 몰이 실패 정당 말 집중 조명 아침 편집자 주 한정애 더불어민주당 정책위 의장 오른쪽 최대 집 대한의사협회 장이 서울 여의도 민주당 사 정책 협약 이행 합의서 서명 후 주먹 사진 뉴스1 민주당 합의 이행 최선 더불어민주당 건의 논평 대한의사협회 정책 이행 합의 내용 사회 거리 두기 단계 연장 내용 정부 여당 날 신종 코로나바이러스 감염증 코로나 19 안정 의대 정원 공공 의대 확대 논의 전면 중단 의료 집단 휴지 최종 합의 민주당 환영 메시지 다음 민주당 논평 최인호 민주당 수석 대변인 의료 집단 휴 진 문제 해결 오늘 오전 대한의사협회 민주당 정책 협약 이행 합의 한정애 정책위 의장 대화 이후 사흘 대화 결과 생각 대한의사협회 민주당 코로나 19 확산 때 그동안 의료 계가 반대 의대 정원 확대 공공 의대 신설 관련 논의 중단 코로나 19 안정 이후 협의체 구성 논의 민주당 공공 보건 의료 기관 경쟁력 확보 의료인 근로 조건 개선 전반 의료 환경 개선 지원 방안 마련 노력 우여곡절 오늘 합의 코로나 19 위기 국민 환자 결정 생각 오늘 계기 집단 휴지 의료인 복귀 코로나 19 위기 극복 기대 민주당 합의 이행 최선 최대 집 대한의사협회 장과 한정애 더불어민주당 정책위 의장 서울 여의도 민주당 사 정책 협약 이행 합의서 사인 사진 합의서 사진 연합뉴스 국민 힘 극 합의 환영 정책 검토 국민 힘 건의 논평 정부 여당 의료 극 합의 내용 뉴딜 펀드 비판 재판장 증언 거부 조국 법무부 장관 비판 사회 거리 두기 단계 연장 내용 관련 기사 안철수 국민 힘 행사 강연 자로 연대 추경 안팎 소 상공 선별 지원 위법 기업 매출 벌금 신동근 안철수 홍준표 꼴 보수 민주당 출신 성비 위 입 양향자 성의 대개 조 필요 문 대통령 지지도 소폭 하락 국민 힘 개명 효과 최대 집 전공의 반발 움직임 이상 집단행동 국민 힘 안철수 야권 혁신 논의 이재명 안철수 본인 패륜 초심 고민정 논란 정부 의료진 갈라치 모습 불편 국민 힘 정부 여당 합의 환영 메시지 공공 의대 정책 검증 다음 국민 힘 논평 김은혜 국민 힘 대변인 진료 현장 복귀 결정 의료진 정부 의료진 사이에서 조정 국민 대신 감사 말씀 위기 때 국민 저력 코로나 위기 극복 힘 다행 생각 다만 코로나 19 시기 의료진 자극 정부 정책 추진 정부 사회 갈등 잘못 되풀이 복기 개선 국민 힘 정기 국회 과정 의료 파업 원인 공공 의대 의대 증원 정책 검토 검증 계획 반복 폭염 호우 속 코로나 19 사투 의사 간호사 자원봉사 구급대 노고 위로 감사 말씀 모두 국민 코로나 우리 힘 극복 국민 힘 노력 지난 경기도 안양시 안양 중앙공원 국회의원 선거 안양 동안 을 출마 정의당 추 혜 선 후보 지지 호소 사진 연합뉴스 추 혜 선 비판 성명 정의당 정의당 건의 논평 정부 여당 의료 극 합의 내용 추 혜 선 정의당 의원 내용 추 혜 선 의원 행보 정의당 지도부 입장 최근 당 대표 출마 선언 박 창 진 갑 근절 특별 위원장 정도 비판 목소리 다음 정의당 논평 조 혜민 정의당 대변인 오전 정의당 상무 위원회 추 혜 선 의원 최근 LG유플러스 자문 관련 정의당 견지 원칙 판단 20대 국회 정무 위원회 소속 의원 활동 추 의원 국회의원 임기 종료 후 피감 기관 취업 재벌 기업 감시 정의당 의원 신뢰 행위 오후 정의당 추 혜 선 의원 자문 취임 철회 공식 요청 답변 일 인해 우려 당원 시민 말씀 정의당 진보 정치 가치 훼손 정의당 다운 길 노력 박 능 후 보건 복지부 장관 왼쪽 최대 집 대한의사협회 장이 서울 종로구 정부서울청사 집단 휴지 중단 의대 정원 확대 의료 정책 협의 의정 협의체 구성 내용 합의문 서명식 참석 사진 신경 훈 기자 .com 국민의당 의료 정책 원점 논의 환영 국민의당 건의 논평 부동산 거래 분석 비판 내용 정부 여당 의료 극 합의 내용 의사 출신 안철수 대표 국민의당 의료 집단 휴지 적극 목소리 다음 국민의당 논평 안혜지 국민의당 대변인 의료 계가 보름 집단 휴지 사태 마무리 의료 현장 복귀 정부 여당 의료 계가 밤샘 협상 끝 오늘 공공 의료 확충 정책 관련 조항 최종 합의 도출 의료진 현장 복귀 진심 환영 협상 정부 관계자 노력 감사 문제 의료 정책 원점 논의 집권 여당 정부 이해 당사자 의료 계가 참여 공동 협의체 구성 논의 천만다행 도출 합의 안 의료 국민 전체 불안 우려 초유 사태 발생 정부 이행 향후 현실 실효 공공 의료 정책 마련 이번 갈등 해결 하심 마음 결단 정부 관계자 숨 의료 현장 복귀 의료진 모두 감사 마음 조준 혁 한경 닷 ...
