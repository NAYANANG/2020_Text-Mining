# %%
from konlpy.tag import Komoran

komoran=Komoran()
# Out:
# /usr/local/lib/python3.6/dist-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
import pandas as pd
import os
import numpy as np
def RS_POS_tag(x):
    rs=pd.read_csv('/home/u1013/schtm_osy_lsm_kjh/Crawling_Dataset/{0}'.format(x))
    rs=rs.drop('Unnamed: 0',axis=1)
    rs_text=np.array(rs.loc[:,'Text'].tolist())
    rs_pos_words=[]
    for i in range(len(rs)):
        rs_pos_words.append(komoran.pos(rs_text[i]))
    total_text=[]
    pos_text=[]
    keyword=['부동산정책']
    for j in range(len(rs)):
        text_list=rs_pos_words[j]
        for i in range(len(text_list)):
            if text_list[i][1] not in ('SF','SP','SS','SE','SO','SW') and text_list[i][0] not in keyword:
                pos_text.append(text_list[i][:])
        total_text.append(pos_text)
        pos_text=[]
    sub_pos=[]
    selected_pos=[]
    for j in range(len(total_text)):
        pos_list=total_text[j]
        for i in range(len(pos_list)):
            if pos_list[i][1] in ('NNG','NNP','MM','MAG'):
                sub_pos.append(pos_list[i][0])
    return sub_pos

# %%
tag=RS_POS_tag('KTV국민방송_부동산정책.csv')

# %%
import wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from os import path

FONT_PATH = './gungsuh.ttf'

noun_text=''
for i in tag:
    noun_text=noun_text+' '+i
wordcloud=WordCloud(max_font_size=60,relative_scaling=.5,font_path=FONT_PATH).generate(noun_text)
plt.figure()
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import pickle

with open('KTV국민방송_부동산정책.txt','wb') as f:
    pickle.dump(tag,f)

# %%
with open('KTV국민방송_부동산정책.txt','rb') as f:
    read=pickle.load(f)
    print(read)
# Out:
# ['녹취', '문재인', '대통령', '9월 10일', '비상', '경제', '회의', '정부', '긴급', '대책', '규모', '추경', '편성', '8월', '중순', '광복절', '집회', '규모', '집단', '감염', '확산', '집합', '금지', '제한', '업종', '소상', '공인', '자영업자', '피해', '속출', '소상', '공인', '자영업자', '추가경정예산', '안', '녹취', '문재인', '대통령', '9월 10일', '비상', '경제', '회의', '전체', '추경', '규모', '절반', '소상', '공인', '자영업자', '최대', '현금', '지원', '녹취', '홍', '남', '경제', '부총리', '9월 10일', '비상', '경제', '회의', '합동', '브리핑', '모든', '한정', '재원', '조금', '더', '피해', '계층', '조금', '더', '직접', '실질', '지원', '뜻', '선별', '집중', '차등', '맞춤', '녹취', '박영선', '중소', '벤처기업', '장관', '9월 23일', '국세청', '보', '행정', '정보', '활용', '신속', '지급', '대상', '소상', '공인', '확인', '피해', '소상', '공인', '맞춤', '지원', '녹취', '박영선', '중소', '벤처기업', '장관', '9월 23일', '일반', '업종', '19년', '연', '매출', '이하', '20년', '매출', '전년', '감소', '소상', '공인', '인', '모두', '만원', '지원', '피해', '업종', '정부', '집합', '금지', '영업', '제한', '인해', '영업', '어려움', '소상', '공인', '노래', '연습장', '주점', '이번', '국회', '지원', '예산', '반영', '유흥', '주점', '콜라텍', '집합', '금지', '업종', '만원', '수도권', '일반', '음식점', '제과점', '영업', '제한', '업종', '만원', '지급', '소상', '공인', '새', '희망', '자금', '피해', '업종', '영업', '중단', '노래', '연습장', '방', '유흥', '주점', '콜라텍', '영업', '제한', '수도권', '음식점', '제과점', '새', '희망', '자금', '지급', '제외', '업종', '유흥', '도박', '업', '복권', '판매업', '성인', '오락실', '전화방', '고액', '자산', '포함', '업종', '부동', '산업', '골프장', '운영업', '전문', '직종', '변호사', '회계사', '약국', '녹취', '홍', '남', '경제', '부총리', '9월 10일', '비상', '경제', '회의', '합동', '브리핑', '이외', '폐업', '소상', '공인', '취업', '창업', '인당', '폐업', '점포', '도전', '장려금', '지원', '계획', '예산', '소요', '계상', '심사', '지급', '신속', '녹취', '박영선', '중소', '벤처기업', '장관', '9월 23일', '이번', '만원', '지원', '지원', '대상', '피해', '업종', '지자체', '목록', '확인', '추석', '이후', '지원', '예정', '국민방송', '케이블', '방송', '위성방송', '.kr', '한국정책방송원', '무단', '전재', '배포', '금지', '신경', '앵커', '국세청', '고의', '재산', '세금', '내지', '고액', '체납', '추적', '조사', '이', '방조', '사람', '고발', '처벌', '계획', '임', '하경', '기자', '임', '하경', '기자', '영상', '제공', '국세청', '옷장', '속', '가방', '열자', '돈뭉치', '집안', '곳곳', '돈', '약', '세금', '돈이 없어', '시골집', '신고', '한', '체납', '아내', '명의', '고가', '아파트', '호화', '생활', '가택', '수색', '흥분', '다른', '체납', '고성', '녹취', '체납', '감옥', '제가', '죄', '서랍', '안', '수표', '장이', '무더기', '부동산', '돈', '수표로', '양도소득세', '체납', '강남', '활동', '한', '변호사', '수입', '금액', '세금', '내지', '집', '순금', '골프', '회원권', '명품', '시계', '핸드백', '발견', '압류', '국세청', '고의', '재산', '세금', '내지', '액체', '납자', '추적', '조사', '실시', '배우자', '가족', '재산', '편법', '은닉', '경우', '친인척', '금융', '조회', '자금', '출처', '철저히', '검증', '녹취', '정철', '우', '국세청', '징세', '법무', '국장', '고가', '주택', '거주', '호화', '사치', '생활', '영위', '악의', '액체', '납자', '거주지', '집중', '수색', '실시', '아울러', '악의', '체납', '처분', '면', '탈', '경우', '체납', '자와', '그', '방조자', '체납', '처분', '면', '범', '고발', '병행', '계획', '국세청', '올해', '1월', '8월', '체납', '추적', '조사', '총', '징수', '고발', '조치', '정부', '앞으로', '강도', '추적', '조사', '내년', '고액', '상습', '체납', '최대', '유치장', '감치', '엄정', '대응', '방침', '영상', '취재', '안', '욱', '이수경', '영상', '편집', '김종석', '다만', '세금', '납부', '어려움', '생계', '체납', '처분', '유예', '세', '정지원', '실시', '예정', 'KTV', '국민방송', '케이블', '방송', '위성방송', '.kr', '한국정책방송원', '무단', '전재', '배포', '금지', '이', '시각', '뉴스', '코로나', '19', '신규', '확진', '지역', '발생', '오늘', '0시', '기준', '코로나', '19', '신규', '확진', '지역', '발생', '해외', '유입', '확인', '사망자', '추가', '누적', '집계', '귀경', '길', '고속도로', '정체', '시작', '밤', '해소', '귀경', '행렬', '시작', '가운데', '오후', '2시', '사이', '정체', '절정', '밤', '해소', '전망', '한국도로공사', '코로나', '19', '여파', '예년', '이동', '평소', '일요일', '정도', '정체', '예상', '정', '총리', '어르신', '행복', '대한민국', '건강', '노인의 날', '정세균', '국무총리', '어르신', '행복', '대한민국', '미래', '건강', '말', '정', '총리', '기초', '연금', '지급', '대상', '확대', '치매', '국가', '책임', '노인', '복지', '정책', '강화', '복지', '건강', '미래', '최선', '노력', '다', '8월', '부동', '산업', '매출', '최대', '폭', '감소', '8월', '부동', '산업', '생산', '지수', '전달', '하락', '최대', '폭', '감소', '기록', '통계청', '부동산', '시장', '과열', '정책', '이후', '8월', '주택', '거래', '감소', '부동산', '매출액', '설명', '배추', '한', '포기', '돌파', '장마', '태풍', '영향', '장마', '태풍', '영향', '올해', '배추', '생산량', '지난해', '보다', '값', '두', '배', '수준', '지난달', '배추', '소매', '가격', '포기', '지난해', '달', '수준', '비교', '배', '미', '국무부', '도발', '관여', '미', '국무부', '종전', '선언', '관련', '싱가포르', '정상회담', '모든', '약속', '균형', '합의', '도달', '접근', '의향', '있다', '북한', '기회', '창', '지금', '관여', '역내', '불안정',  ...
