# %%
from selenium import webdriver
import os
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv
import urllib.request as ur

# %%
pd.read_csv('./COVID_국민일보.csv',encoding='utf-8')
# Out:
#     Unnamed: 0 Press                                            Title  \
# 0            0  국민일보  나눠주고 도와주는 사람들 '나도람FC', 수도권 일부 가맹점에 방역 위한 마스크 배포
# 1            1  국민일보                         국립 인천대 창작 뮤지컬 집으로 11일 개막
# 2            2  국민일보                  윤건영 “변창흠 국토부 장관 내정자 비난, 이해 안 가”
# 3            3  국민일보                [전문] 문 대통령 “권력기관 개혁 다음 정부로 안 미룬다”
# 4            4  국민일보           원·달러 환율, 하루 만에 15원 가까이 떨어져…원화 강세 언제까지?
# ..         ...   ...                                              ...
# 94          94  국민일보               [속보] 문 대통령 “의료계 총파업, 법 집행으로 강력 대처”
# 95          95  국민일보                     中우한 대학들 속속 개학… 코로나 방역 자신감 과시
# 96          96  국민일보                   기아대책, 에리트레아 난민 코로나 방역 물품 지원 나서
# 97          97  국민일보                 中 풀파티·맥주축제에 국제영화제까지…코로나방역 자신감 과시
# 98          98  국민일보                    김종인 “대통령 과도한 공포조장,민주국가서 지양해야”
#
#                                                  Text
# 0   코로나19 장기화로 생계 유지에 어려움을 겪는 가맹점이 늘고 있다. 이런 가운데 이...
# ...
