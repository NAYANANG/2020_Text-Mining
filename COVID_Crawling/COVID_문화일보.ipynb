# %%
from selenium import webdriver
import os
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv
import urllib.request as ur

# %%
browser=webdriver.Chrome('chromedriver.exe')
browser.get('http://mhsearch.munhwa.com/search.php?startCount=0&query={0}&mode=basic&sort=RANK&collection=news&range=A&startDate=1970.01.01&endDate=2020.10.11&searchField=ALL&reQuery=&reporter=&reQuery=&reporter=&searchField=ALL&div_code=ALL&sort=RANK&dateCheck=1&sYearView=2020&sMonView=07&sDayView=11&eYearView=2020&eMonView=10&eDayView=11'.format('코로나방역'))
url=[]

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[2]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[3]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[4]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[5]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[6]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[7]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[7]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[8]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[9]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[10]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[11]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])
browser.find_element_by_xpath('//*[@id="content-wrap"]/div[1]/div[2]/div/a[12]').click()

html=browser.page_source
soup=BeautifulSoup(html,'html.parser')
attr=soup.select('ul.list_thumb>li >div>a')
for urls in attr:
    url.append(urls['href'])

# %%
dict={}

for i in range(len(url)):
    browser.get(url[i])
    time.sleep(1)
    html=browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    title=soup.find('span',{'class':'title'}).text
    title=title.replace('\r','').replace('\n','').replace('\t','')
    text=soup.find('div',{'id':'NewsAdContent'}).text
    text=text.replace('\n','').replace('\t','').replace('\r','').replace('\xa0','')
    dict[title]=text

# %%
pd.read_csv('./COVID_문화일보.csv',encoding='utf-8')
# Out:
#     Unnamed: 0 Press                                              Title  \
# 0            0  문화일보                                ‘방역 독재’로는 코로나 못 이긴다
# 1            1  문화일보                잉글랜드축구대표팀 코로나19 방역 지침 위반, 경찰조사 없을 듯
# 2            2  문화일보               코로나19 확진자 100명 안팎서 등락…오늘부터 ‘추석 특별방역’
# 3            3  문화일보                         홍남기 “코로나 방역, 경제 유지에 중점 둬야”
# 4            4  문화일보                 北, 남측 공무원 사살·불태운 사건에 침묵…코로나 방역만 강조
# ..         ...   ...                                                ...
# 95          95  문화일보                 파우치 “美 승인 코로나19 백신 나오면 망설임 없이 접종”
# 96          96  문화일보                   LGU+‘5G 방역로봇’ 선보여 얼굴인식 솔루션업체와 협약
# 97          97  문화일보              정은경 “코로나19 폭발적 확산 억제…신규확진 100명 이하 목표”
# 98          98  문화일보  김종인 “코로나 경제위기는 정치권이 해결해야”…이낙연 “4차 추경 하는쪽으로 결론나...
# 99          99  문화일보                        ‘코로나 국회’ 1일 개원…공수처 등 격돌 불가피
#
#                                                  Text
# 0   김용호 경희대 평화복지대학원 특임교수개천절 집회 막은 살벌한 풍경 시민 자율 빛났던...
# 1     잉글랜드 축구대표팀의 태미 에이브러햄과 벤 칠웰(이상 첼시), 제이던 산초(도르...
# 2   추석 연휴 인구이동량 많아 재확산의 ‘기폭제’ 될 우려 제기민속놀이 포함 대규모 모...
# 3   G20 재무 보건회의서 강조홍남기 부총리 겸 기획재정부장관은 18일 신종 코로나바이...
# 4   ‘박왕자씨 피격’ 당시에는 다음날 담화 발표북한이 서해상에서 남측 공무원을 사살한 ...
# ..                                                ...
# 95    미국의 신종 코로나바이러스 감염증(코로나19) 방역 핵심 책임자인 앤서니 파우치...
# 96    LG유플러스가 신종 코로나바이러스 감염증(코로나19) 방역을 위한 ‘5세대(G)...
# 97    방역당국은 최근 신종 코로나바이러스 감염증(코로나19) 신규 확진자 수가 나흘 ...
# 98  與·野대표 첫 회동 ‘화기애애’李 “與·野의 공통 공약 입법화”金 “여러 정치 상황...
# 99  10월 5일부터 3주간 국정감사국회는 1일 개원식을 시작으로 21대 첫 정기국회가 ...
#
# [100 rows x 4 columns]
